# %% [markdown]
# # Data Science

# %% [markdown]
# 데이터를 단순히 분류하거나 분석하는 것 말고 데이터 속에 담긴 패턴이나 미래 예측에 도움이 되는 신호를 찾는 것.

# %% [markdown]
# 통계학 : 표본 조사를 통해 전체를 추론하고 예측

# %% [markdown]
# 데이터 과학 (Data Science) : 통계학의 분석방법론, 머신러닝, 딥러닝, 텍스트 마이닝, 추천시스템 등

# %% [markdown]
# # Data Scientist의 Skillset

# %% [markdown]
# Computer Science

# %% [markdown]
# Maths & Statistics

# %% [markdown]
# Business / Domain Expertise

# %% [markdown]
#  - Machine Learning & Traditional Software & Data Analysis

# %% [markdown]
#  -> Data Science

# %% [markdown]
# # Data Science Process

# %% [markdown]
# (목표 설정) -> 데이터 수집 -> 데이터 전처리 -> 데이터 분석 -> 데이터 예측 -> 데이터 시각화 / 서비스화

# %% [markdown]
# # 데이터 수집 (Collecting)

# %% [markdown]
# - Database

# %% [markdown]
# - File (CSV, XML, JSON)

# %% [markdown]
# - Web Crawling

# %% [markdown]
# - IoT sensor data

# %% [markdown]
# - Survey

# %% [markdown]
# # 데이터 전처리 (Preprocessing)

# %% [markdown]
# - 결측치(누락된 데이터) 처리 : 데이터 삭제, 대체 (최대값, 최소값, 중앙값 등), 예측 모델을 활용한 값 삽입

# %% [markdown]
# - 이상치 처리 : 입력 오류 or 자연발생 -> 데이터 삭제, 대체, feature 추가 (분석할 요소인지 판단)

# %% [markdown]
# - Feature Engineering (특성 공학) :
#         Scaling (feature의 단위를 변경), Binning(수치형 -> 범주형)
#         Transform(feature를 분리하거나 연산 - 날짜, 주중/주말)
#         Encoding(범주형 -> 수치형)

# %% [markdown]
# # 데이터 분석 (Exploratory Data Analysis)

# %% [markdown]
# - 탐색적 데이터 분석 : 각 데이터에 어떤 의미가 있는지, 어떤 형태의 데이터인지 등 파악하기

# %% [markdown]
#  - 각 변수가 어떤 의미인지 파악 : Meta Data, Data Description

# %% [markdown]
# - 범주형 (Categorical Data) : 데이터가 정해진 범주 내에서 나오는 형태
#                          : 성별, 혈액형, 성공여부 (Nominal Data),
#                          : 학점, 효과정도 (Ordinal Data)

# %% [markdown]
# - 수치형 (Numerical Data) : 연속적인 수치 데이터 형태
#                          : 발생횟수, 학급인원 (Discrete Data)
#                          : 키, 몸무게, 혈압 (Continuous Data)

# %% [markdown]
# - 기술 통계 : 최대값, 최소값, 최빈값, 평균값, 중앙값, 분산, 표준편차, 사분위수

# %% [markdown]
# - 변수간 상관관계, 독립 여부 확인

# %% [markdown]
# # 데이터 예측

# %% [markdown]
# - 머신러닝 단계 (Machine Learning)

# %% [markdown]
#  - - 지도 학습 (Supervised Learning) : Linear Regression, SVM, Decision Tree, KNN, Ensemble Model, etc

# %% [markdown]
#  - - 비지도 학습 (Unsupervised Learning) : Clustering, Dimensionality Reduction, etc

# %% [markdown]
#  - 딥러닝 (Deep Learning)

# %% [markdown]
#   - - 음성인식, 영상인식, 자연어처리 : Deep Neural Network, CNN, RNN, Deep Q-Network, GAN, etc

# %% [markdown]
# # 데이터 시각화 / 서비스화

# %% [markdown]
#  - 사용자 (End User) 한테 분석/예측한 데이터 전달. 사용자가 데이터를 활용할 수 있도록.

# %% [markdown]
#  - 시각화 : Scatter Plot, Bar Chart, Pie Chart, Box Plot, Histogram, Heatmap

# %% [markdown]
#  - 서비스화 : Web Service, Mobile Service, Desktop Application

# %% [markdown]
# # 데이터의 중요성

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  - Forbes에서 인용한 CrowdFlower의 설문 결과에 따르면 데이터 분석가는 80% 이상의 시간을 데이터 수집/전처리 과정에 사용한다.

# %% [markdown]
# - Garbage in Garbage out : 좋은 자료를 모으고, 적정하게 정리하여 넣지 않으면 가치를 발견하기 어렵다. (쓰레기 자료를 사용하면 쓰레기 결과가 나온다.)

# %% [markdown]
# # 단계별 Python 패키지

# %% [markdown]
# - Collecting : BeautifulSoup, Selenium, PyMySQL, PyMongo, etc

# %% [markdown]
# - Preprocessing : Numpy, Pandas, etc

# %% [markdown]
# - Explorary Data Analysis : Numpy, Pandas, Matplotlib, Seaborn, etc

# %% [markdown]
# - Machine Learning : Scikit Learn, SparkML, Tensorflow, Kears, Pytorch, etc

# %% [markdown]
# - Communication / Reporting / Building Data Product : Matplotlib, Seaborn, Django, Flask, etc
