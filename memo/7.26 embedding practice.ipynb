# %%
from embedding_as_service_client import EmbeddingClient

en = EmbeddingClient(host='13.124.31.20', port=8989)

# %%
en.encode(texts=['spongebob', 'patrick'])
# 텍스트는 항상 리스트로 넘겨 줄 것

# spongebob이라는 문자를 100개의 숫자로 백터화 시킨 것
# 2차원 array
# 1번째 : spongebob 문자열 벡터화
# 2번째 : patrick 문자열 벡터화
# Out:
# array([[ 1.3655e-02, -5.8408e-04,  8.0422e-03,  4.0975e-03, -4.4776e-03,
#          3.0752e-03,  2.3077e-03,  4.3977e-03, -1.3934e-03,  4.2365e-03,
#          8.3279e-03,  8.0728e-04, -2.3739e-02, -2.2488e-03, -2.2451e-03,
#          1.0375e-02,  5.3982e-04,  7.2713e-03,  3.0635e-03,  9.3510e-03,
#         -6.4073e-03, -3.2998e-03, -8.0970e-03,  2.9328e-04,  1.0772e-02,
#          6.7335e-03, -5.7083e-03, -4.1211e-03, -1.3706e-03, -9.0026e-03,
#         -8.2910e-03, -1.1708e-03,  3.1040e-03,  2.3310e-03,  1.7783e-03,
#         -3.5311e-03,  9.0070e-03, -3.2390e-04,  3.9396e-03,  1.1251e-03,
#         -9.9132e-03, -7.0610e-03,  1.5224e-03, -2.6288e-03, -4.7516e-03,
#          3.1617e-03, -2.5085e-03,  2.5989e-03,  8.6606e-04,  3.2380e-04,
#         -2.4789e-03, -1.7286e-03, -4.5863e-03, -4.1138e-04, -5.1172e-03,
#         -1.1211e-03, -8.0351e-04,  4.0554e-03,  3.2094e-04, -4.0359e-03,
#         -8.3214e-03, -6.4648e-04, -1.4068e-04, -4.5706e-03, -4.4914e-03,
# ...
